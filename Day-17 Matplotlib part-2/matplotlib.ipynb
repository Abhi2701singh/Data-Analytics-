# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
from PIL import Image

# %% [markdown]
# ## Pie chart

# %%
x=[10,20,50,30]
y=['A','B','C','D']

plt.pie(x,labels=y)
plt.show()

# %%
x=[10,20,50,30]
y=['A','B','C','D']

plt.pie(x,labels=y)
plt.legend()
plt.show()
